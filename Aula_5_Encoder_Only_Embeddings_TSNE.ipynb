# %% [markdown]
# # Aula 5 - Aplicação de modelo Encoder-only para Embedding e Visualização
#
# Este notebook demonstra como carregar um modelo Transformer encoder-only treinado, aplicar o modelo para gerar embeddings de uma coleção de sentenças/documentos e visualizar os embeddings em 2D usando T-SNE.

# %% [markdown]
# ## 1. Carregar bibliotecas necessárias

# %%
import torch
import torch.nn as nn
from torch.nn import functional as F
import numpy as np
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE
